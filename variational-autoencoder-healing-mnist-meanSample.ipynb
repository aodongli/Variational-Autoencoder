# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import os
import sys
import numpy as np
from scipy import stats

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['text.usetex'] = True
matplotlib.rc('text.latex', preamble=r'\usepackage{amsmath}\usepackage{amssymb}')
import matplotlib.pyplot as plt

old_stdout = sys.__stdout__

# %%
# dataset
from torch.utils.data import Dataset, DataLoader
    

class NoisyData(Dataset):
    def __init__(self, x):
        self.x = x
    
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        image = self.x[idx]
        image = image.reshape(784)
        
        return image

def get_dataloader(x, batch_size, num_worker, shuffle):
    '''Use PyTorch Dataset to enable multiprocessing to prepare data.
    '''
    dataset = NoisyData(x)
    
    init_fun = np.random.seed()
    dataloader = DataLoader(
        dataset, 
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=num_worker,
        worker_init_fn=init_fun
    )
    return dataloader

# %% [markdown]
# Variational Auto-encoder ELBO:
#
# \begin{align}
# & E_{q(z|x)} [\log p(x,z) - \log q(z|x)] \\
# = & E_{q(z|x)} [\log p(x|z)] - KL[q(z|x)||p(z)] \\
# \propto & - \sum_{i=1}^N (\hat x_i - x_i)^2 - \sum_{i=1}^K KL(q_{z_i|x}||p(z_i))
# \end{align}
# where $N$ and $K$ is the dimension of the input and latent variable, respectively.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_probability as tfp
tfd = tfp.distributions

from datetime import datetime
def print_log(*args):
    print("[{}]".format(datetime.now()), *args)
    sys.stdout.flush()

class VariationalAutoEncoder:
    def __init__(self, x_dim, z_dim, net_size, lr=0.001, kl_weight=1.0):
        
        # 'z_dim, activation, loss' can be tuned
        
        # reset the default graph otherwise the variable initialization will get
        # slower because all models create the variables and operations in the
        # same graph
        tf.reset_default_graph()
        
        self.x_dim = x_dim
        self.z_dim = z_dim
        self.lr = lr
        self.kl_weight = kl_weight
        
        with tf.compat.v1.variable_scope('placeholder'):
            x_shape = [None] + [self.x_dim]
            self.x = tf.placeholder(
                tf.float32, 
                shape=x_shape)
        
        with tf.compat.v1.variable_scope('networks'):
            self.recog = keras.Sequential(
                [
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(self.z_dim*2, activation=None),
                ]
            )
            self.gen = keras.Sequential(
                [
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(self.x_dim, activation=None),
                ]
            )
        
        with tf.compat.v1.variable_scope('z'):
            self.p_z = tfd.Normal(
                loc=[0.] * self.z_dim,
                scale=[1.] * self.z_dim,
                name='p_z_dist')
            
            self.z_param = self.recog(self.x)
            self.z_mean = self.z_param[:, :self.z_dim]
            self.z_std = tf.math.softplus(self.z_param[:, self.z_dim:])

            self.q_z = tfd.Normal(
                loc=self.z_mean,
                scale=self.z_std,
                name='q_z_dist')
            
            self.z = self.q_z.sample()
            
        with tf.compat.v1.variable_scope('x'):
            self.re_x_logit = self.gen(self.z)
            self.p_re_x = tfd.Bernoulli(logits=self.re_x_logit, name='p_x_z_dist')
            self.re_x = self.p_re_x.mean()
        
        with tf.compat.v1.variable_scope('training_loss'):
            self.rec_error = -tf.reduce_sum(
                self.p_re_x.log_prob(self.x), axis=-1)
            self.kl_loss = tf.reduce_sum(tfd.kl_divergence(self.q_z, self.p_z, name='KL'), axis=-1)
            self.nelbo = self.rec_error + self.kl_weight * self.kl_loss
            self.ave_nelbo = tf.reduce_mean(self.nelbo)
        
        self.optimizer = tf.train.AdamOptimizer(
            learning_rate=self.lr)
        self.train_step = self.optimizer.minimize(self.ave_nelbo)
        
        # sample from prior
        self.z_from_prior = self.p_z.sample()
        self.x_sample_logit = self.gen(tf.expand_dims(self.z_from_prior, axis=0))
        self.p_x_sample = tfd.Bernoulli(logits=self.x_sample_logit)
        self.x_sample = self.p_x_sample.mean()
        
    # initialization
    def init_session(self):
        # Initializing the variables
        init = tf.global_variables_initializer()

        # launch a session
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = False #True
        self.sess = tf.Session(config=config)

        self.sess.run(init)
        
    def train(self, tr_loader, no_epochs=500, te_loader=None):
        costs = []
        rec_error = []
        kl_loss = []
        
        for epoch_idx in range(no_epochs):
            epoch_cost = 0.
            epoch_lik_cost = 0.
            epoch_kl_cost = 0.
            for batch_idx, tr_batch in enumerate(tr_loader):
                tr_x = tr_batch
                _, cost, kl, rec = self.sess.run(
                    [
                        self.train_step,
                        self.ave_nelbo,
                        self.kl_loss,
                        self.rec_error
                    ],
                    feed_dict={
                        self.x: tr_x
                    }
                )
                
                epoch_cost += cost
                epoch_lik_cost += np.mean(rec)
                epoch_kl_cost += np.mean(kl)
                
                costs.append(cost)
                rec_error.append(np.mean(rec))
                kl_loss.append(np.mean(kl))
                
            batch_idx += 1
            epoch_cost /= batch_idx
            epoch_lik_cost /= batch_idx
            epoch_kl_cost /= batch_idx
            
            print_log("Epoch:", '%04d' % (epoch_idx+1), 
                "total cost=", 
                "{:.9f}".format(epoch_cost), 
                "log-likelihood term=", 
                "{:.9f}".format(epoch_lik_cost), 
                "kl/regluarization term=", 
                "{:.9f}".format(epoch_cost - epoch_lik_cost))
            
        return costs, rec_error, kl_loss

# %%
mini_batchsize = 64
no_epochs = 50
lr = 0.001
z_dim = 100
net_size = 200

# data
x_train = np.load('dataset/small_healing_mnist_tr.npy')
x_test = np.load('dataset/small_healing_mnist_te.npy')

mnist_tr_loader = get_dataloader(x_train, mini_batchsize, 4, True)

# model
vae = VariationalAutoEncoder(x_dim=784, z_dim=z_dim, net_size=net_size, lr=lr)
vae.init_session()

# train
costs, rec_error, kl_loss = vae.train(mnist_tr_loader, no_epochs=no_epochs)
# Out:
# WARNING:tensorflow:From /home/aodongl1/.conda/envs/py3gpu/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# [2021-06-06 13:16:36.720042] Epoch: 0001 total cost= 404.398502686 log-likelihood term= 401.937845752 kl/regluarization term= 2.460656934
# [2021-06-06 13:16:39.647932] Epoch: 0002 total cost= 395.045988721 log-likelihood term= 393.377433252 kl/regluarization term= 1.668555469
# [2021-06-06 13:16:42.663601] Epoch: 0003 total cost= 394.449149219 log-likelihood term= 392.998114258 kl/regluarization term= 1.451034961
# [2021-06-06 13:16:45.657126] Epoch: 0004 total cost= 394.246992920 log-likelihood term= 392.856674414 kl/regluarization term= 1.390318506
# [2021-06-06 13:16:48.599429] Epoch: 0005 total cost= 394.124752588 log-likelihood term= 392.806160254 kl/regluarization term= 1.318592334
# [2021-06-06 13:16:51.711600] Epoch: 0006 total cost= 394.119459375 log-likelihood term= 392.750965234 kl/regluarization term= 1.368494141
# [2021-06-06 13:16:54.658727] Epoch: 0007 total cost= 394.044829736 log-likelihood term= 392.714073096 kl/regluarization term= 1.330756641
# [2021-06-06 13:16:57.740914] Epoch: 0008 total cost= 393.950502832 log-likelihood term= 392.644811084 kl/regluarization term= 1.305691748
# [2021-06-06 13:17:00.840247] Epoch: 0009 total cost= 393.903511230 log-likelihood term= 392.606164600 kl/regluarization term= 1.297346631
# [2021-06-06 13:17:03.820337] Epoch: 0010 total cost= 393.873969238 log-likelihood term= 392.557785107 kl/regluarization term= 1.316184131
# [2021-06-06 13:17:06.842697] Epoch: 0011 total cost= 393.826198828 log-likelihood term= 392.512409033 kl/regluarization term= 1.313789795
# [2021-06-06 13:17:09.827535] Epoch: 0012 total cost= 393.781049268 log-likelihood term= 392.454875195 kl/regluarization term= 1.326174072
# [2021-06-06 13:17:12.832896] Epoch: 0013 total cost= 393.786086865 log-likelihood term= 392.419181836 kl/regluarization term= 1.366905029
# [2021-06-06 13:17:15.865805] Epoch: 0014 total cost= 393.768321924 log-likelihood term= 392.407001709 kl/regluarization term= 1.361320215
# [2021-06-06 13:17:18.886042] Epoch: 0015 total cost= 393.708869141 log-likelihood term= 392.370054980 kl/regluarization term= 1.338814160
# [2021-06-06 13:17:21.896435] Epoch: 0016 total cost= 393.730149219 log-likelihood term= 392.362467773 kl/regluarization term= 1.367681445
# [2021-06-06 13:17:24.953257] Epoch: 0017 total cost= 393.732578906 log-likelihood term= 392.345449707 kl/regluarization term= 1.387129199
# [2021-06-06 13:17:28.102911] Epoch: 0018 total cost= 393.725496436 log-likelihood term= 392.360624902 kl/regluarization term= 1.364871533
# [2021-06-06 13:17:31.255978] Epoch: 0019 total cost= 393.813789893 log-likelihood term= 392.386441309 kl/regluarization term= 1.427348584
# [2021-06-06 13:17:34.225677] Epoch: 0020 total cost= 393.692717090 log-likelihood term= 392.306793359 kl/regluarization term= 1.385923730
# [2021-06-06 13:17:37.124150] Epoch: 0021 total cost= 393.664169971 log-likelihood term= 392.310539941 kl/regluarization term= 1.353630029
# [2021-06-06 13:17:40.232135] Epoch: 0022 total cost= 393.650560449 log-likelihood term= 392.285674512 kl/regluarization term= 1.364885937
# [2021-06-06 13:17:43.264372] Epoch: 0023 total cost= 393.655606885 log-likelihood term= 392.302664990 kl/regluarization term= 1.352941895
# [2021-06-06 13:17:46.294975] Epoch: 0024 total cost= 393.660850342 log-likelihood term= 392.281693506 kl/regluarization term= 1.379156836
# [2021-06-06 13:17:49.452294] Epoch: 0025 total cost= 393.632543018 log-likelihood term= 392.283466797 kl/regluarization term= 1.349076221
# [2021-06-06 13:17:52.568589] Epoch: 0026 total cost= 393.622990625 log-likelihood term= 392.263825684 kl/regluarization term= 1.359164941
# [2021-06-06 13:17:55.576802] Epoch: 0027 total cost= 393.610306885 log-likelihood term= 392.253808447 kl/regluarization term= 1.356498438
# [2021-06-06 13:17:58.630264] Epoch: 0028 total cost= 393.627704932 log-likelihood term= 392.245664355 kl/regluarization term= 1.382040576
# [2021-06-06 13:18:01.397899] Epoch: 0029 total cost= 393.596586572 log-likelihood term= 392.255638525 kl/regluarization term= 1.340948047
# [2021-06-06 13:18:04.368320] Epoch: 0030 total cost= 393.619446387 log-likelihood term= 392.222276514 kl/regluarization term= 1.397169873
# [2021-06-06 13:18:07.367496] Epoch: 0031 total cost= 393.610548242 log-likelihood term= 392.221010107 kl/regluarization term= 1.389538135
# [2021-06-06 13:18:10.376957] Epoch: 0032 total cost= 393.586259277 log-likelihood term= 392.221829004 kl/regluarization term= 1.364430273
# [2021-06-06 13:18:13.516875] Epoch: 0033 total cost= 393.602991211 log-likelihood term= 392.221910840 kl/regluarization term= 1.381080371
# [2021-06-06 13:18:16.522332] Epoch: 0034 total cost= 393.576871045 log-likelihood term= 392.231528320 kl/regluarization term= 1.345342725
# [2021-06-06 13:18:19.600013] Epoch: 0035 total cost= 393.600973437 log-likelihood term= 392.231496484 kl/regluarization term= 1.369476953
# [2021-06-06 13:18:22.273933] Epoch: 0036 total cost= 393.595979346 log-likelihood term= 392.224238428 kl/regluarization term= 1.371740918
# [2021-06-06 13:18:25.266632] Epoch: 0037 total cost= 393.570019336 log-likelihood term= 392.199116748 kl/regluarization term= 1.370902588
# [2021-06-06 13:18:28.372041] Epoch: 0038 total cost= 393.556100146 log-likelihood term= 392.181834473 kl/regluarization term= 1.374265674
# [2021-06-06 13:18:31.406962] Epoch: 0039 total cost= 393.577061475 log-likelihood term= 392.205828662 kl/regluarization term= 1.371232813
# [2021-06-06 13:18:34.362767] Epoch: 0040 total cost= 393.551748828 log-likelihood term= 392.178685742 kl/regluarization term= 1.373063086
# [2021-06-06 13:18:37.384668] Epoch: 0041 total cost= 393.545577002 log-likelihood term= 392.162241357 kl/regluarization term= 1.383335645
# [2021-06-06 13:18:40.490495] Epoch: 0042 total cost= 393.553022607 log-likelihood term= 392.196404053 kl/regluarization term= 1.356618555
# [2021-06-06 13:18:43.487208] Epoch: 0043 total cost= 393.555250537 log-likelihood term= 392.178447021 kl/regluarization term= 1.376803516
# [2021-06-06 13:18:46.464018] Epoch: 0044 total cost= 393.577445068 log-likelihood term= 392.193441260 kl/regluarization term= 1.384003809
# [2021-06-06 13:18:49.426366] Epoch: 0045 total cost= 393.527926074 log-likelihood term= 392.197207861 kl/regluarization term= 1.330718213
# [2021-06-06 13:18:52.330473] Epoch: 0046 total cost= 393.535481641 log-likelihood term= 392.161626172 kl/regluarization term= 1.373855469
# [2021-06-06 13:18:55.407784] Epoch: 0047 total cost= 393.632100244 log-likelihood term= 392.254150635 kl/regluarization term= 1.377949609
# [2021-06-06 13:18:58.444610] Epoch: 0048 total cost= 393.643059863 log-likelihood term= 392.204204688 kl/regluarization term= 1.438855176
# [2021-06-06 13:19:01.565143] Epoch: 0049 total cost= 393.521887158 log-likelihood term= 392.169387305 kl/regluarization term= 1.352499854
# [2021-06-06 13:19:04.571435] Epoch: 0050 total cost= 393.538341064 log-likelihood term= 392.147090771 kl/regluarization term= 1.391250293

# %%
fig = plt.Figure(figsize=[5,5])
axes = fig.subplots(3,1)

ax = axes[0]
ax.plot(costs)
ax.set_xlabel('Iteration')
ax.set_ylabel('NELBO')

ax = axes[1]
ax.plot(rec_error)
ax.set_xlabel('Iteration')
ax.set_ylabel('REC Loss')

ax = axes[2]
ax.plot(kl_loss)
ax.set_xlabel('Iteration')
ax.set_ylabel('KL Loss')

fig.tight_layout()
fig
# Out:
# /home/aodongl1/.conda/envs/py3gpu/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: tight_layout : falling back to Agg renderer

# %%
# reconstruct a test image
x_te = x_test[0]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# reconstruct a test image
x_te = x_test[1]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# reconstruct a test image
x_te = x_test[2]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# reconstruct a test image
x_te = x_test[3]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# reconstruct a test image
x_te = x_test[4]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# samples
fig = plt.Figure(figsize=(7,7))
axes = fig.subplots(10,10)

for i in range(10):
    for j in range(10):
        ax = axes[i,j]
        
        re_x = vae.sess.run([vae.x_sample])[0]
        
        ax.imshow(re_x.reshape(28,28))
        ax.set_xticks([])
        ax.set_xticks([], minor=True)
        ax.set_yticks([])
        ax.set_yticks([], minor=True)

fig

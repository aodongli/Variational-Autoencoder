# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import os
import sys
import numpy as np
from scipy import stats

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['text.usetex'] = True
matplotlib.rc('text.latex', preamble=r'\usepackage{amsmath}\usepackage{amssymb}')
import matplotlib.pyplot as plt

old_stdout = sys.__stdout__

# %%
# dataset
from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        image = self.x[idx]
        label = self.y[idx]
        image = image.reshape(784)
        return image, label

def get_dataloader(x, y, batch_size, num_worker, shuffle):
    '''Use PyTorch Dataset to enable multiprocessing to prepare data.
    '''
    dataset = Data(x, y)
    
    init_fun = np.random.seed()
    dataloader = DataLoader(
        dataset, 
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=num_worker,
        worker_init_fn=init_fun
    )
    return dataloader

# %% [markdown]
# Variational Auto-encoder ELBO:
#
# \begin{align}
# & E_{q(z|x)} [\log p(x,z) - \log q(z|x)] \\
# = & E_{q(z|x)} [\log p(x|z)] - KL[q(z|x)||p(z)] \\
# \propto & - \sum_{i=1}^N (\hat x_i - x_i)^2 - \sum_{i=1}^K KL(q_{z_i|x}||p(z_i))
# \end{align}
# where $N$ and $K$ is the dimension of the input and latent variable, respectively.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_probability as tfp
tfd = tfp.distributions

from datetime import datetime
def print_log(*args):
    print("[{}]".format(datetime.now()), *args)
    sys.stdout.flush()

class VariationalAutoEncoder:
    def __init__(self, x_dim, z_dim, net_size, lr=0.001, kl_weight=1.0):
        
        # 'z_dim, activation, loss' can be tuned
        
        # reset the default graph otherwise the variable initialization will get
        # slower because all models create the variables and operations in the
        # same graph
        tf.reset_default_graph()
        
        self.x_dim = x_dim
        self.z_dim = z_dim
        self.lr = lr
        self.kl_weight = kl_weight
        
        with tf.compat.v1.variable_scope('placeholder'):
            x_shape = [None] + [self.x_dim]
            self.x = tf.placeholder(
                tf.float32, 
                shape=x_shape)
        
        with tf.compat.v1.variable_scope('networks'):
            self.recog = keras.Sequential(
                [
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(self.z_dim*2, activation='relu'), # THIS IS A RELU FUNCTION
                ]
            )
            self.gen = keras.Sequential(
                [
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(net_size, activation='relu'),
                    layers.Dense(self.x_dim, activation='relu'), # THIS IS A RELU FUNCTION
                ]
            )
        
        with tf.compat.v1.variable_scope('z'):
            self.p_z = tfd.Normal(
                loc=[0.] * self.z_dim,
                scale=[1.] * self.z_dim,
                name='p_z_dist')
            
            self.z_param = self.recog(self.x)
            self.z_mean = self.z_param[:, :self.z_dim]
            self.z_std = tf.math.softplus(self.z_param[:, self.z_dim:])

            self.q_z = tfd.Normal(
                loc=self.z_mean,
                scale=self.z_std,
                name='q_z_dist')
            
            self.z = self.q_z.sample()
            
        self.re_x = self.gen(self.z)
        
        with tf.compat.v1.variable_scope('training_loss'):
            self.rec_error = tf.reduce_sum(tf.square(self.x - self.re_x), axis=-1)
            self.kl_loss = tf.reduce_sum(tfd.kl_divergence(self.q_z, self.p_z, name='KL'), axis=-1)
            self.nelbo = self.rec_error + self.kl_weight * self.kl_loss
            self.ave_nelbo = tf.reduce_mean(self.nelbo)
        
        self.optimizer = tf.train.AdamOptimizer(
            learning_rate=self.lr)
        self.train_step = self.optimizer.minimize(self.ave_nelbo)
        
        # sample from prior
        self.z_from_prior = self.p_z.sample()
        self.x_sample = self.gen(tf.expand_dims(self.z_from_prior, axis=0))
        
    # initialization
    def init_session(self):
        # Initializing the variables
        init = tf.global_variables_initializer()

        # launch a session
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = False #True
        self.sess = tf.Session(config=config)

        self.sess.run(init)
        
    def train(self, tr_loader, no_epochs=500, te_loader=None):
        costs = []
        rec_error = []
        kl_loss = []
        
        for epoch_idx in range(no_epochs):
            epoch_cost = 0.
            epoch_lik_cost = 0.
            epoch_kl_cost = 0.
            for batch_idx, tr_batch in enumerate(tr_loader):
                tr_x, _, = tr_batch
                _, cost, kl, rec = self.sess.run(
                    [
                        self.train_step,
                        self.ave_nelbo,
                        self.kl_loss,
                        self.rec_error
                    ],
                    feed_dict={
                        self.x: tr_x
                    }
                )
                
                epoch_cost += cost
                epoch_lik_cost += np.mean(rec)
                epoch_kl_cost += np.mean(kl)
                
                costs.append(cost)
                rec_error.append(np.mean(rec))
                kl_loss.append(np.mean(kl))
                
            batch_idx += 1
            epoch_cost /= batch_idx
            epoch_lik_cost /= batch_idx
            epoch_kl_cost /= batch_idx
            
            print_log("Epoch:", '%04d' % (epoch_idx+1), 
                "total cost=", 
                "{:.9f}".format(epoch_cost), 
                "log-likelihood term=", 
                "{:.9f}".format(epoch_lik_cost), 
                "kl/regluarization term=", 
                "{:.9f}".format(epoch_cost - epoch_lik_cost))
            
        return costs, rec_error, kl_loss

# %%
mini_batchsize = 64
no_epochs = 50
lr = 0.001
z_dim = 500
net_size = 1000

# data
(x_train, y_train), (x_test, y_test) = \
    tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32')
y_train = np.squeeze(y_train)
x_test = x_test.astype('float32')
y_test = np.squeeze(y_test)
# x_train /= 255
# x_test /= 255

mnist_tr_loader = get_dataloader(x_train, y_train, mini_batchsize, 4, True)

# model
vae = VariationalAutoEncoder(x_dim=784, z_dim=z_dim, net_size=net_size, lr=lr)
vae.init_session()

# train
costs, rec_error, kl_loss = vae.train(mnist_tr_loader, no_epochs=no_epochs)
# Out:
# WARNING:tensorflow:From /home/aodongl1/.conda/envs/py3gpu/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# [2021-06-06 02:25:03.352795] Epoch: 0001 total cost= 1768339.513059702 log-likelihood term= 1747554.706356610 kl/regluarization term= 20784.806703092
# [2021-06-06 02:25:08.349212] Epoch: 0002 total cost= 1075081.544909382 log-likelihood term= 1059717.411713753 kl/regluarization term= 15364.133195629
# [2021-06-06 02:25:13.350519] Epoch: 0003 total cost= 956451.159848081 log-likelihood term= 942593.924906716 kl/regluarization term= 13857.234941365
# [2021-06-06 02:25:18.125506] Epoch: 0004 total cost= 890339.918976546 log-likelihood term= 877490.120069296 kl/regluarization term= 12849.798907249
# [2021-06-06 02:25:22.962704] Epoch: 0005 total cost= 852020.783315565 log-likelihood term= 840027.561367271 kl/regluarization term= 11993.221948294
# [2021-06-06 02:25:28.019782] Epoch: 0006 total cost= 823047.383262260 log-likelihood term= 811740.440698294 kl/regluarization term= 11306.942563966
# [2021-06-06 02:25:33.018108] Epoch: 0007 total cost= 802166.063299574 log-likelihood term= 791333.555037313 kl/regluarization term= 10832.508262260
# [2021-06-06 02:25:37.952731] Epoch: 0008 total cost= 784036.105210554 log-likelihood term= 773687.725746269 kl/regluarization term= 10348.379464286
# [2021-06-06 02:25:42.743004] Epoch: 0009 total cost= 770417.291844350 log-likelihood term= 760369.239339019 kl/regluarization term= 10048.052505331
# [2021-06-06 02:25:47.814158] Epoch: 0010 total cost= 756827.152785181 log-likelihood term= 747138.230210554 kl/regluarization term= 9688.922574627
# [2021-06-06 02:25:52.914556] Epoch: 0011 total cost= 745921.576359275 log-likelihood term= 736525.559901386 kl/regluarization term= 9396.016457889
# [2021-06-06 02:25:57.661874] Epoch: 0012 total cost= 734609.182502665 log-likelihood term= 725428.610807569 kl/regluarization term= 9180.571695096
# [2021-06-06 02:26:02.545023] Epoch: 0013 total cost= 725344.503131663 log-likelihood term= 716434.533648721 kl/regluarization term= 8909.969482942
# [2021-06-06 02:26:07.476654] Epoch: 0014 total cost= 717545.918176972 log-likelihood term= 708836.240005331 kl/regluarization term= 8709.678171642
# [2021-06-06 02:26:12.435443] Epoch: 0015 total cost= 711072.358941898 log-likelihood term= 702488.669442964 kl/regluarization term= 8583.689498934
# [2021-06-06 02:26:17.341340] Epoch: 0016 total cost= 704682.493536780 log-likelihood term= 696280.199626866 kl/regluarization term= 8402.293909915
# [2021-06-06 02:26:22.470694] Epoch: 0017 total cost= 695561.340285181 log-likelihood term= 687264.042843817 kl/regluarization term= 8297.297441364
# [2021-06-06 02:26:27.204827] Epoch: 0018 total cost= 677484.337153518 log-likelihood term= 669318.274720149 kl/regluarization term= 8166.062433369
# [2021-06-06 02:26:32.224013] Epoch: 0019 total cost= 674278.883128998 log-likelihood term= 666129.774586887 kl/regluarization term= 8149.108542111
# [2021-06-06 02:26:37.182544] Epoch: 0020 total cost= 665726.334421642 log-likelihood term= 657731.338885927 kl/regluarization term= 7994.995535714
# [2021-06-06 02:26:41.787492] Epoch: 0021 total cost= 664310.801972281 log-likelihood term= 656403.558568763 kl/regluarization term= 7907.243403518
# [2021-06-06 02:26:46.684684] Epoch: 0022 total cost= 657865.593416844 log-likelihood term= 649997.313299574 kl/regluarization term= 7868.280117271
# [2021-06-06 02:26:51.415022] Epoch: 0023 total cost= 654356.101312633 log-likelihood term= 646523.549906716 kl/regluarization term= 7832.551405917
# [2021-06-06 02:26:56.424760] Epoch: 0024 total cost= 650810.664245736 log-likelihood term= 643032.445362473 kl/regluarization term= 7778.218883262
# [2021-06-06 02:27:01.180770] Epoch: 0025 total cost= 645843.378564765 log-likelihood term= 638136.442230810 kl/regluarization term= 7706.936333955
# [2021-06-06 02:27:05.980605] Epoch: 0026 total cost= 644156.619536247 log-likelihood term= 636507.349413646 kl/regluarization term= 7649.270122601
# [2021-06-06 02:27:10.694117] Epoch: 0027 total cost= 641508.462153518 log-likelihood term= 633876.923840618 kl/regluarization term= 7631.538312900
# [2021-06-06 02:27:15.599134] Epoch: 0028 total cost= 638983.939299040 log-likelihood term= 631379.589885394 kl/regluarization term= 7604.349413646
# [2021-06-06 02:27:20.300062] Epoch: 0029 total cost= 636730.931136727 log-likelihood term= 629170.666211354 kl/regluarization term= 7560.264925373
# [2021-06-06 02:27:25.292810] Epoch: 0030 total cost= 633169.524553571 log-likelihood term= 625627.804271055 kl/regluarization term= 7541.720282516
# [2021-06-06 02:27:30.297052] Epoch: 0031 total cost= 632263.720648987 log-likelihood term= 624787.201892324 kl/regluarization term= 7476.518756663
# [2021-06-06 02:27:34.807313] Epoch: 0032 total cost= 628764.720515725 log-likelihood term= 621287.381030117 kl/regluarization term= 7477.339485608
# [2021-06-06 02:27:39.515503] Epoch: 0033 total cost= 628546.100513060 log-likelihood term= 621120.401385927 kl/regluarization term= 7425.699127132
# [2021-06-06 02:27:44.499637] Epoch: 0034 total cost= 625558.632595949 log-likelihood term= 618118.831789712 kl/regluarization term= 7439.800806237
# [2021-06-06 02:27:49.241510] Epoch: 0035 total cost= 622946.693796642 log-likelihood term= 615498.666877665 kl/regluarization term= 7448.026918977
# [2021-06-06 02:27:54.110695] Epoch: 0036 total cost= 620715.651452559 log-likelihood term= 613352.238239606 kl/regluarization term= 7363.413212953
# [2021-06-06 02:27:59.044312] Epoch: 0037 total cost= 614748.678504797 log-likelihood term= 607371.117937100 kl/regluarization term= 7377.560567697
# [2021-06-06 02:28:03.945809] Epoch: 0038 total cost= 600123.325059968 log-likelihood term= 592770.984375000 kl/regluarization term= 7352.340684968
# [2021-06-06 02:28:08.951558] Epoch: 0039 total cost= 598303.099946695 log-likelihood term= 590978.794442964 kl/regluarization term= 7324.305503731
# [2021-06-06 02:28:13.875962] Epoch: 0040 total cost= 596897.486107409 log-likelihood term= 589561.599013859 kl/regluarization term= 7335.887093550
# [2021-06-06 02:28:18.779776] Epoch: 0041 total cost= 594968.266724414 log-likelihood term= 587648.973680704 kl/regluarization term= 7319.293043710
# [2021-06-06 02:28:23.909135] Epoch: 0042 total cost= 593923.034648188 log-likelihood term= 586639.618803305 kl/regluarization term= 7283.415844883
# [2021-06-06 02:28:28.818150] Epoch: 0043 total cost= 591591.207322761 log-likelihood term= 584322.284514925 kl/regluarization term= 7268.922807836
# [2021-06-06 02:28:33.843866] Epoch: 0044 total cost= 591562.323061034 log-likelihood term= 584277.844016524 kl/regluarization term= 7284.479044510
# [2021-06-06 02:28:38.884266] Epoch: 0045 total cost= 590764.056603145 log-likelihood term= 583507.239705490 kl/regluarization term= 7256.816897655
# [2021-06-06 02:28:43.968920] Epoch: 0046 total cost= 586807.678404851 log-likelihood term= 579562.439365672 kl/regluarization term= 7245.239039179
# [2021-06-06 02:28:48.965706] Epoch: 0047 total cost= 584009.252598614 log-likelihood term= 576772.281949627 kl/regluarization term= 7236.970648987
# [2021-06-06 02:28:54.023506] Epoch: 0048 total cost= 582437.850113273 log-likelihood term= 575196.738239606 kl/regluarization term= 7241.111873667
# [2021-06-06 02:28:59.073951] Epoch: 0049 total cost= 581609.402285448 log-likelihood term= 574405.930803571 kl/regluarization term= 7203.471481876
# [2021-06-06 02:29:04.296392] Epoch: 0050 total cost= 580458.682269456 log-likelihood term= 573248.516091418 kl/regluarization term= 7210.166178038

# %%
fig = plt.Figure(figsize=[5,5])
axes = fig.subplots(3,1)

ax = axes[0]
ax.plot(costs)
ax.set_xlabel('Iteration')
ax.set_ylabel('NELBO')

ax = axes[1]
ax.plot(rec_error)
ax.set_xlabel('Iteration')
ax.set_ylabel('REC Loss')

ax = axes[2]
ax.plot(kl_loss)
ax.set_xlabel('Iteration')
ax.set_ylabel('KL Loss')

fig.tight_layout()
fig
# Out:
# /home/aodongl1/.conda/envs/py3gpu/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: tight_layout : falling back to Agg renderer

# %%
# reconstruct a test image
x_te = x_test[0]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# reconstruct a test image
x_te = x_test[1]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# reconstruct a test image
x_te = x_test[2]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# reconstruct a test image
x_te = x_test[3]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# reconstruct a test image
x_te = x_test[4]
x_te = x_te.reshape(784)
re_x = vae.sess.run([vae.re_x], feed_dict={vae.x: [x_te]})[0][0]

fig = plt.Figure()
axes = fig.subplots(nrows=1, ncols=2)
axes[0].imshow(x_te.reshape(28,28))
axes[1].imshow(re_x.reshape(28,28))

fig

# %%
# samples
fig = plt.Figure(figsize=(7,7))
axes = fig.subplots(10,10)

for i in range(10):
    for j in range(10):
        ax = axes[i,j]
        
        re_x = vae.sess.run([vae.x_sample])[0]
        
        ax.imshow(re_x.reshape(28,28))
        ax.set_xticks([])
        ax.set_xticks([], minor=True)
        ax.set_yticks([])
        ax.set_yticks([], minor=True)

fig
